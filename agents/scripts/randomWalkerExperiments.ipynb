# %% [markdown]
# # Random Walker Experiments
#
# Author: K. Voudouris, 2023 (c) All Rights Reserved.
#
# Contact: kv301@cam.ac.uk; k.voudouris14@googlemail.com; [Twitter @KozzyVoudouris](https://twitter.com/KozzyVoudouris); [GitHub @kozzy97](https://github.com/kozzy97)
#
# Date: July 2023
#
# This script runs a series of random walkers on the object permanence tests and stores the results in a MySQL database. It relies on a few things:
#
# 1. All the dependencies are installed, particularly that animalai is installed properly. I recommend using a conda environment and setting up an ipykernel for running this notebook.
# 2. AnimalAI is installed as an executable in the `env` folder.
# 3. A recent installation of MySQL, configured with a database, user, and password, as well as the local (or remote) address to store on. MySQL WorkBench is a good IDE for interacting with MySQL (this was created with WorkBench 8.0)
# 4. A CSV file in the same directory as this notebook called `databaseConnectionDetails.csv`, containing columns `database_name`, `hostname`, `username`, and `password` for database connection, with the values in the next row. This is gitignored.

# %%
import numpy as np
import os
import pandas as pd
import pymysql
import random
import sys

from animalai.envs.environment import AnimalAIEnvironment
from collections import deque
from gym_unity.envs import UnityToGymWrapper
from scipy.special import softmax

import sys
sys.path.append('../src')

from randomWalkers import RandomWalker #import the random walker class
from yamlHandling import find_yaml_files #this function finds the yaml files in a directory.
from yamlHandling import yaml_combinor #this function combines a batch of yaml files and saves the output in a temporary folder. This means we can run inference on batches of tests at once.

# %% [markdown]
# ## Database Connection
#
# A function for connecting to the database.

# %%
def databaseConnector(databaseCredentialsCSV: str):
    databaseCredentials = pd.read_csv(databaseCredentialsCSV)
    
    connection = pymysql.connect(
        host=databaseCredentials['hostname'].iloc[0],
        user=databaseCredentials['username'].iloc[0],
        password=databaseCredentials['password'].iloc[0],
        database=databaseCredentials['database_name'].iloc[0]
        )

    mycursor = connection.cursor()

    print(f"Connected to database: `{databaseCredentials['database_name'].iloc[0]}` at `{databaseCredentials['hostname'].iloc[0]}` with user `{databaseCredentials['username'].iloc[0]}`.")

    return mycursor, connection

# %%
mycursor, connection = databaseConnector('databaseConnectionDetails.csv')

mycursor.close()

print("Connection checked and closed.")
# Out:
# Connected to database: `opiaagets` at `localhost` with user `agenttester`.
# Connection checked and closed.

# %% [markdown]
# ## Paths
#
# Provide the paths to the directory containing the configs being tested over, as well as the path the animal ai environment. Finally, provide a location for generating temporary files of combined configs. This defaults to the parent directory of the github repository, to prevent results being pushed accidentally.

# %%
configuration_folder = "../../configs/tests_agents"

env_path = "../../env/AnimalAI"

temp_folder_location = "../../.."

# %% [markdown]
# ## Add All Tasks In Directory To Database
#
# Iterate through the directory and find yaml files and their task names.

# %%
rerunInstanceTable = False

mycursor, connection = databaseConnector('databaseConnectionDetails.csv')

yaml_files, task_names = find_yaml_files(configuration_folder)

if rerunInstanceTable:
    dropTable = "DROP TABLE IF EXISTS randomwalkerinstanceresults, randomwalkerintrainstanceresults, instances;"
    mycursor.execute(dropTable)
    
    sql = "CREATE TABLE instances(instanceid INT AUTO_INCREMENT PRIMARY KEY, instancename VARCHAR(750) UNIQUE NOT NULL);"
    mycursor.execute(sql)

for instance in task_names:
    try:
        insertQuery = "INSERT INTO instances(instancename) VALUES('" + str(instance) + "');"
        mycursor.execute(insertQuery)
        connection.commit()
    except:
        print(f"Task {instance} has already been added to this table. Moving to next.")

mycursor.close()
# Out:
# Connected to database: `opiaagets` at `localhost` with user `agenttester`.
# Task OP-STC-Allo-CVChick-1Occluder-Left-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Left-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Left-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Left-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Left-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Left-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Left-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Right-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Right-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Right-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Right-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Right-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Right-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-1Occluder-Right-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Left-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Left-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Left-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Left-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Left-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Left-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Left-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Right-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Right-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Right-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Right-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Right-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Right-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-2Occluder-Right-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Left-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Left-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Left-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Left-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Left-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Left-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Left-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Right-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Right-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Right-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Right-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Right-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Right-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-CVChick-Low-Right-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5CloseLeftMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5CloseRightMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5FarLeftMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G0.5FarRightMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5CloseLeftMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5CloseRightMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5FarLeftMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1.5FarRightMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1CloseLeftMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1CloseRightMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1FarLeftMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G1FarRightMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2CloseLeftMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2CloseRightMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2FarLeftMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-12CupGrid-G2FarRightMid-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5LFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5MFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G0.5RFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1LFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1MFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G1RFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5LFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5MFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2.5RFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2LFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2MFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RClose-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-Brown-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-DarkBlue-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-DarkBlue-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-DarkGreen-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-DarkGreen-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-Grey-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-Grey-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-OffWhite-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-OffWhite-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-RND-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G2RFar-RND-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G3LClose-Beige-0-OpLava.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G3LClose-Beige-0-OPQ.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-3CupFC-1G3LClose-Brown-0-OpLava.yml has already been added to this table. Moving to next.
# ...
# Task OP-STC-Allo-PCTB-4CupGridClose-G1CloseRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridClose-G1FarLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridClose-G1FarRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridClose-G2CloseLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridClose-G2CloseRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridClose-G2FarLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridClose-G2FarRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G0.5CloseLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G0.5CloseRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G0.5FarLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G0.5FarRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G1.5CloseLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G1.5CloseRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G1.5FarLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G1.5FarRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G1CloseLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G1CloseRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G1FarLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G1FarRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G2CloseLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G2CloseRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G2FarLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridFar-G2FarRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G0.5CloseLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G0.5CloseRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G0.5FarLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G0.5FarRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G1.5CloseLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G1.5CloseRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G1.5FarLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G1.5FarRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G1CloseLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G1CloseRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G1FarLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G1FarRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G2CloseLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G2CloseRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G2FarLeft-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-4CupGridMid-G2FarRight-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G0.5CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G0.5CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G0.5CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G0.5CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G0.5FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G0.5FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G0.5FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G0.5FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1.5CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1.5CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1.5CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1.5CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1.5FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1.5FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1.5FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1.5FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G1FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G2CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G2CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G2CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G2CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G2FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G2FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G2FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseFar-G2FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G0.5CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G0.5CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G0.5CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G0.5CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G0.5FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G0.5FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G0.5FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G0.5FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1.5CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1.5CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1.5CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1.5CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1.5FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1.5FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1.5FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1.5FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G1FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G2CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G2CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G2CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G2CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G2FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G2FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G2FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridCloseMid-G2FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G0.5CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G0.5CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G0.5CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G0.5CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G0.5FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G0.5FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G0.5FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G0.5FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1.5CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1.5CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1.5CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1.5CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1.5FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1.5FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1.5FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1.5FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G1FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G2CloseLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G2CloseLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G2CloseRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G2CloseRightFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G2FarLeftClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G2FarLeftFar-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G2FarRightClose-NA-0-NA.yml has already been added to this table. Moving to next.
# Task OP-STC-Allo-PCTB-8CupGridMidFar-G2FarRightFar-NA-0-NA.yml has already been added to this table. Moving to next.

# %% [markdown]
# ## Agents
#
# Dictionaries of parameters to define some random walker agents. Note that these agents move quite slowly. They take one step forwards then pause for one step. This is to reduce the effect of momentum in the environment so their paths are more accurate.
#
# The first agent is a simple fixed-step random walker. The walker moves 15 steps forwards, and then turns for 10 steps, with a probability of 0.5 of turning left or right. This serves as a very simple baseline.

# %%
fixed_action_walker = {'saccade_distribution' : 'fixed',
                       'angle_distribution' : 'fixed',
                       'max_saccade_length' : 15,
                       'max_angle_steps': 10,
                       'angle_fixed_randomise_turn': True,
                       'aai_seed' : 2023,
                       'agent_tag' : 'Random Walker Fixed Forwards Saccade 15 Angle 10'}

# %% [markdown]
# The next agent is a common model of foraging in animals. It is a Rayleight flight. Saccades are sampled from the normal distribution with a mean of 15 and a standard deviation of 5. If negative values are sampled the agent goes backwards that many steps, so the agent will tend to go forwards but occasionally go backwards. Angles are sampled uniformly between 1 and 60 steps of turning. Each turn is 6 degrees, making 60 steps be a full turn. Choice of left and right is randomised with probability 0.5.

# %%
rayleigh_flight = {'saccade_distribution' : 'normal',
                   'angle_distribution' : 'uniform',
                   'saccade_norm_mu' : 15,
                   'saccade_norm_sig' : 5,
                   'max_angle_steps': 60,
                   'angle_fixed_randomise_turn': True,
                   'backwards_action' : True,
                   'aai_seed' : 2023,
                   'agent_tag' : 'Random Walker Rayleigh Flight Norm Saccade mu 15 sig 5 Uniform Angles 1 to 60'}

# %% [markdown]
# The next agent is another common model of foraging in animals. It is a levy/cauchy flight. Saccades are sampled from the cauchy distribution, centred around 15. If negative values are sampled the agent goes backwards that many steps, so the agent will tend to go forwards but occasionally it will go backwards. Angles are sampled uniformly between 1 and 60 steps of turing. Each turn is 6 degrees, making 60 steps be a full turn. Choice of left and right is randomised with probability 0.5.

# %%
levy_flight = {'saccade_distribution' : 'cauchy',
               'angle_distribution' : 'uniform',
               'saccade_cauchy_mode' : 15,
               'max_angle_steps': 60,
               'angle_fixed_randomise_turn': True,
               'backwards_action' : True,
               'aai_seed' : 2023,
               'agent_tag' : 'Random Walker Levy Flight Cauchy Saccade mode 15 Uniform Angles 1 to 60'}

# %% [markdown]
# The next agent is an extension of the Rayleigh flight. Angles are also sampled from a normal distribution centred around 0 with a standard deviation of 4 so it tends to explore in front of it (standard deviation of 24 degrees to each side) but occasionally turns further around.

# %%
rayleigh_flight_norm_angles = {'saccade_distribution' : 'normal',
                               'angle_distribution' : 'normal',
                               'saccade_norm_mu' : 15,
                               'saccade_norm_sig' : 5,
                               'angle_norm_mu': 0,
                               'angle_norm_sig': 24,
                               'backwards_action' : True,
                               'aai_seed' : 2023,
                               'agent_tag' : 'Random Walker Rayleigh Flight Norm Saccade mu 15 sig 5 Norm Angles mu 0 sd'}

# %% [markdown]
# The next agent is an extension of the Levy/Cauchy flight. Angles are also sampled from the Cauchy distribution centred around 0, so it tends to explore in front of it but given the Cauchy distribution might take big turns occasionally (due to heavy tails).

# %%
levy_flight_cauchy_angles = {'saccade_distribution' : 'cauchy',
                             'angle_distribution' : 'cauchy',
                             'saccade_cauchy_mode' : 15,
                             'angle_cauchy_mode': 0,
                             'angle_fixed_randomise_turn': True,
                             'backwards_action' : True,
                             'aai_seed' : 2023,
                             'agent_tag' : 'Random Walker Levy Flight Cauchy Saccade mode 15 Cauchy Angles mode 0'}

# %%
rerunAgentTable = False

mycursor, connection = databaseConnector('databaseConnectionDetails.csv')

if rerunAgentTable:
    dropTable = "DROP TABLE IF EXISTS randomwalkerinstanceresults, randomwalkerintrainstanceresults, randomwalkers;"
    mycursor.execute(dropTable)
    
    sql = "CREATE TABLE `randomwalkers` (`agentid` INT AUTO_INCREMENT PRIMARY KEY, `agent_tag` VARCHAR(300) UNIQUE, `aai_seed` INT, `max_saccade_length` INT,  `max_angle_steps` INT,  `saccade_distribution` VARCHAR(10), `angle_distribution` VARCHAR(10), `saccade_norm_mu` FLOAT(8), `saccade_norm_sig` FLOAT(8), `saccade_beta_alpha` FLOAT(8), `saccade_beta_beta` FLOAT(8), `saccade_cauchy_mode` FLOAT(8), `saccade_gamma_kappa` FLOAT(8), `saccade_gamma_theta` FLOAT(8), `saccade_weibull_alpha` FLOAT(8), `saccade_poisson_lambda` FLOAT(8), `angle_fixed_randomise_turn` BOOL, `angle_norm_mu` FLOAT(8), `angle_norm_sig` FLOAT(8), `angle_beta_alpha` FLOAT(8), `angle_beta_beta` FLOAT(8), `angle_cauchy_mode` FLOAT(8), `angle_gamma_kappa` FLOAT(8), `angle_gamma_theta` FLOAT(8), `angle_weibull_alpha` FLOAT(8), `angle_poisson_lambda` FLOAT(8), `angle_correlation` FLOAT(8), `backwards_action` BOOL);"
    mycursor.execute(sql)

mycursor.close()
# Out:
# Connected to database: `opiaagets` at `localhost` with user `agenttester`.

# %%
def agentToDB (cur, dictionary : dict):
    keys = ', '.join(dictionary.keys())
    values = ', '.join(
        f"'{value}'" if not isinstance(value, (int, float, bool)) else str(int(value))
        if isinstance(value, bool) else str(value)
        for value in dictionary.values()
        )

    query = f"INSERT INTO randomwalkers({keys}) VALUES ({values});"

    try:
        cur.execute(query)
    except:
        print(f"Agent {dictionary['agent_tag']} is already in the database.")
    
    return query

# %%
mycursor, connection = databaseConnector('databaseConnectionDetails.csv')

agentToDB(mycursor, fixed_action_walker)

agentToDB(mycursor, rayleigh_flight)

agentToDB(mycursor, levy_flight)

agentToDB(mycursor, rayleigh_flight_norm_angles)

agentToDB(mycursor, levy_flight_cauchy_angles)

connection.commit()

mycursor.close()
# Out:
# Connected to database: `opiaagets` at `localhost` with user `agenttester`.
# Agent Random Walker Fixed Forwards Saccade 15 Angle 10 is already in the database.
# Agent Random Walker Rayleigh Flight Norm Saccade mu 15 sig 5 Uniform Angles 1 to 60 is already in the database.
# Agent Random Walker Levy Flight Cauchy Saccade mode 15 Uniform Angles 1 to 60 is already in the database.
# Agent Random Walker Rayleigh Flight Norm Saccade mu 15 sig 5 Norm Angles mu 0 sd is already in the database.
# Agent Random Walker Levy Flight Cauchy Saccade mode 15 Cauchy Angles mode 0 is already in the database.

# %% [markdown]
# ## Run Inference And Store
#
# Need to iterate through the dictionaries and run inference.

# %%
mycursor, connection = databaseConnector('databaseConnectionDetails.csv')

rebuildInstanceResultsTables = False

if rebuildInstanceResultsTables:
    print("Rebuilding results tables, dropping if they already exist.")

    dropInstanceResultsTables = "DROP TABLE IF EXISTS randomwalkerinstanceresults, randomwalkerintrainstanceresults;"
    mycursor.execute(dropInstanceResultsTables)
    
    createInstanceTable = "CREATE TABLE randomwalkerinstanceresults(instanceid INT NOT NULL, agentid INT NOT NULL, finalreward FLOAT(53), FOREIGN KEY (instanceid) REFERENCES instances(instanceid), FOREIGN KEY(agentid) REFERENCES randomwalkers(agentid), PRIMARY KEY (instanceid, agentid));"
    mycursor.execute(createInstanceTable)

    createIntraInstanceTable = "CREATE TABLE randomwalkerintrainstanceresults(instanceid INT NOT NULL, agentid INT NOT NULL, step INT NOT NULL, actiontaken INT NOT NULL, stepreward FLOAT(53), xvelocity FLOAT(32), yvelocity FLOAT(32), zvelocity FLOAT(32), xpos FLOAT(32), ypos FLOAT(32), zpos FLOAT(32), FOREIGN KEY (instanceid) REFERENCES instances(instanceid), FOREIGN KEY(agentid) REFERENCES randomwalkers(agentid), PRIMARY KEY(instanceid, agentid, step));"
    mycursor.execute(createIntraInstanceTable)

    print("Tables: randomwalkerinstanceresults and randomwalkerintrainstanceresults have been successfully built.")

mycursor.close()
# Out:
# Connected to database: `opiaagets` at `localhost` with user `agenttester`.
# Rebuilding results tables, dropping if they already exist.
# Tables: randomwalkerinstanceresults and randomwalkerintrainstanceresults have been successfully built.

# %% [markdown]
# Define a function to run the experiments. This takes an agent dictionary and first checks whether any results have been recorded for it. If not, then it proceeds with testing. It does testing in batches, generating a temporary yml file to run training on and storing the final episode reward, as well as the intra-instance results.

# %%
def runRandomWalkerAndStore (cur, con, batch_size: int, agent_dict: dict, yaml_files, task_names, temp_folder_location, agent_inference = False):
    
    # first, check if this agent has been added to the DB already

    select_agent_id = f"SELECT DISTINCT agentid FROM randomwalkers WHERE agent_tag = '{agent_dict['agent_tag']}';"

    cur.execute(select_agent_id)

    agentid = int(cur.fetchone()[0]) #fetch the result, there should just be 1.

    if check == 0:
        # now proceed with testing
        port = 5000 + random.randint( #create random base port.
            0, 2000
            )
        
        batch_counter = 0

        #set seed
        random.seed(agent_dict['aai_seed'])

        for yaml_index in range(0, len(yaml_files), batch_size):

            if ((yaml_index + batch_size)-1) > len(yaml_files) or batch_size > len(yaml_files):
                upper_bound = len(yaml_files)
            else:
                upper_bound = ((yaml_index + batch_size)-1)

            print(f"Running inferences on batch {batch_counter + 1} of {upper_bound+1} files of total {len(yaml_files)}.")

            batch_files = yaml_files[yaml_index:upper_bound]

            batch_file_names = task_names[yaml_index:upper_bound]

            batch_temp_file_name = f"TempConfig_{yaml_index}.yml"

            config_file_path = yaml_combinor(file_list = batch_files, temp_file_location=temp_folder_location, stored_file_name = batch_temp_file_name)

            print("Opening AAI Environment.")

            temp_port = port + yaml_index # increment through ports to prevent calling the same socket.

            aai_env = AnimalAIEnvironment( 
                inference=agent_inference, #Set true when watching the agent
                seed = agent_dict['aai_seed'],
                worker_id=agent_dict['aai_seed'],
                file_name=env_path,
                arenas_configurations=config_file_path,
                base_port=temp_port,
                useCamera=False,
                resolution=4, #make resolution small to improve processing speed - random walkers don't need anything.
                useRayCasts=False,
            )

            env = UnityToGymWrapper(aai_env, uint8_visual=False, allow_multiple_obs=True, flatten_branched=True)

            obs = env.reset()  

            #behavior = list(aai_env.behavior_specs.keys())[0] # by default should be AnimalAI?team=0

            agent = RandomWalker() # initialise agent class

            for key, value in agent_dict.items(): #set the agent attributes to be whatever is in the dictionary, and default otherwsise.
                if hasattr(agent, key):
                    setattr(agent, key, value)

            for _instance in range(len(batch_files)): 

                #get instance ID
                getInstanceIDQuery = f"SELECT instanceid FROM instances WHERE instancename = '{batch_file_names[_instance]}';" #get the instance ID for 

                cur.execute(getInstanceIDQuery)
       
                instanceid = int(cur.fetchone()[0]) #fetch the result, there should just be 1.

                check_agent_instance_query = f"SELECT CASE WHEN EXISTS (SELECT * FROM randomwalkerinstanceresults WHERE agentid = {agentid} AND instanceid = {instanceid}) THEN 1 ELSE 0 END AS AnyData;"

                cur.execute(check_agent_instance_query)

                check_agent_instance = int(cur.fetchone()[0])

                if check_agent_instance == 0:

                    #prepare to run instance
                    done = False

                    episodeReward = 0

                    step_counter = 0
    
                    while not done:

                        saccade_list = agent.get_num_steps_saccade()
            
                        for action in saccade_list:
            
                            obs, reward, done, info = env.step(int(action))

                            #dec, term = aai_env.get_steps(behavior)
                            env.render()
                
                            step_counter += 1

                            episodeReward += reward

                            try:
                                intraInstanceQuery = intraInstanceQuery = f"INSERT INTO randomwalkerintrainstanceresults(instanceid, agentid, step, actiontaken, stepreward, xvelocity, yvelocity, zvelocity, xpos, ypos, zpos) VALUES ({instanceid}, {agentid}, {step_counter}, {action}, {float(episodeReward)}, {obs[0][1]}, {obs[0][2]}, {obs[0][3]}, {obs[0][4]}, {obs[0][5]}, {obs[0][6]});"
                                cur.execute(intraInstanceQuery)
                                con.commit()
            
                            except:
                                print(f"There's something wrong with this step. Here's the query {intraInstanceQuery}")
                                pass

                            if done:
                                obs=env.reset()
                                print(f"Episode Reward: {episodeReward}")
                                done = True #to be sure.
                                break #break the for loop early
                    
                    
                        if not done: # only do turns if episode not done yet.

                            if 'num_angle_steps' not in locals() and agent.angle_distribution == 'normal': #if no turns have been done yet and using normal distribution, then set the central moment to be the prespecified normal_mu
                                prev_angle_central_moment = agent.angle_norm_mu
                            elif 'num_angle_steps' not in locals() and agent.angle_distribution == 'cauchy': #as above
                                prev_angle_central_moment = agent.angle_cauchy_mode
                            elif 'num_angle_steps' in locals():
                                prev_angle_central_moment = num_angle_steps #if turns have been done, then the central moment is whatever number of steps was provided before.
                            else:
                                prev_angle_central_moment = 0

                            angle_list, num_angle_steps = agent.get_num_steps_turn(prev_angle_central_moment)
        
                            for action in angle_list:
            
                                obs, reward, done, info = env.step(int(action))
                
                                step_counter += 1

                                #dec, term = aai_env.get_steps(behavior)
                                env.render()

                                episodeReward += reward

                                try:
                                    intraInstanceQuery = f"INSERT INTO randomwalkerintrainstanceresults(instanceid, agentid, step, actiontaken, stepreward, xvelocity, yvelocity, zvelocity, xpos, ypos, zpos) VALUES ({instanceid}, {agentid}, {step_counter}, {action}, {float(episodeReward)}, {obs[0][1]}, {obs[0][2]}, {obs[0][3]}, {obs[0][4]}, {obs[0][5]}, {obs[0][6]});"
                                    cur.execute(intraInstanceQuery)
                                    con.commit()
            
                                except:
                                    print(f"There's something wrong with this step. Here's the query {intraInstanceQuery}")
                                    pass
                        
                                #if done:
                                #    obs=env.reset()
                                #    break #break the for loop early

                                if done:
                                    print(F"Episode Reward: {episodeReward}")
                                    obs=env.reset()
                                    done = True #to be sure.
                                    break

                    try:
                        insertInstanceResults = f"INSERT INTO randomwalkerinstanceresults(instanceid, agentid, finalreward) VALUES ({instanceid}, {agentid}, {episodeReward});"
                        cur.execute(insertInstanceResults)
                        con.commit()
                        print("Pushing results to database.")
                    except:
                        print("It looks like this agent has already been tested on this instance.")

                else:
                    print("This instance has already been tested on. Skipping.")
                    done = False
                    while not done:
                        obs, reward, done, info = env.step(int(0))
                        env.render()
                    print("Moving to next instance")
                    
            env.close()

            batch_counter += 1

            os.remove(config_file_path)

            print("Moving to next batch.")

    else:
        print("This agent has already been run and is in the database. Skipping so as not to waste time. If you suspect that the agent has not been fully evaluated on all tests, you may want to restart the instances for that agent.")

# %%
agent_dict_list = [fixed_action_walker, rayleigh_flight, levy_flight, rayleigh_flight_norm_angles, levy_flight_cauchy_angles]

yaml_batch_size = 100

for agent_dictionary in agent_dict_list:

    print(f"Running {agent_dictionary['agent_tag']}")
    
    mycursor, connection = databaseConnector('databaseConnectionDetails.csv')

    runRandomWalkerAndStore(mycursor, connection, yaml_batch_size, agent_dict=agent_dictionary, yaml_files=yaml_files, task_names=task_names, temp_folder_location=temp_folder_location, agent_inference=False)

    mycursor.close()
