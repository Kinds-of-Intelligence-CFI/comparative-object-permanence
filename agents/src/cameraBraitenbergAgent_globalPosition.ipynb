# %% [markdown]
# # Braitenberg Vehicle
#
# This agent moves towards green and yellow goals and away from red goals and lava. It can only do that when it sees them in its current field of view. You could easily extend it to make more complex behavioural patterns, like going towards walls, too.

# %%
from animalai.envs.actions import AAIActions, AAIAction
# from animalai.envs.cameraparser import CameraParser
# from animalai.envs.cameraparser import CameraObjects
from animalai.envs.environment import AnimalAIEnvironment
from mlagents_envs.envs.unity_gym_env import UnityToGymWrapper
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Parameters

# %%
aai_seed = 128 # set the seed for the random number generator, and then vary this to make a population of agents

STEP_LENGTH = 15 # how many steps to take before taking a random action, vary this to make a population of agents
NUM_EPISODES = 38 # add number of episodes for testing

agent_inference = True

agent_name = "cameraBraitenbergVehicle"

# %% [markdown]
# ## Paths

# %%
configuration_file = r"/Users/nataszasiwinska/Documents/research_projects/animal-ai-main/configs/combined_short.yml"
env_path = r"/Users/nataszasiwinska/Documents/animal-ai/env/AAI3Mac.app"
log_folder_path = r"/Users/nataszasiwinska/Documents/research_projects/results"

# %%
# Braitenberg vehicle design by M. D. Crosby.
# Adapted by K. Voudouris where noted.
# Further adapted by J. Liu where noted.


class Braitenberg():
    """Implements a simple Braitenberg vehicle agent that heads towards food"""
    def __init__(self, step_length):
        self.actions = AAIActions()
        self.prev_action = self.actions.NOOP
        self.GOODGOAL = np.array([0.7411765, 0.8784314, 0.5411765], dtype=np.float32)
        self.GOODGOALMULTI = np.array([0.9607843,  0.8666667,  0.40784314], dtype=np.float32)
        self.IMMOVABLE = np.array([0.7411765, 0.8784314, 0.5411765], dtype=np.float32), 
        self.forwards_counter = 0
        self.forwards_active = False
        self.last_saw_goal_left = False
        self.last_saw_goal_right = False
        self.last_saw_goal_ahead = False
        self.consecutive_steps_in_same_direction = 0
        

    def get_action_camera(self, obs, step_length, velocity) -> AAIAction:
        """Returns the action to take given the current visual observation"""
        """Agent orientates towards good goal"""
        newAction = self.actions.NOOP
        #if self.ahead(obs, self.GOODGOAL):
        #    newAction = self.actions.FORWARDS
        #elif self.left(obs, self.GOODGOAL):
        #    newAction = self.actions.FORWARDSLEFT
        #elif self.right(obs, self.GOODGOAL):
        #    newAction = self.actions.FORWARDSRIGHT
        #elif self.ahead(obs, self.GOODGOALMULTI):
        #    newAction = self.actions.FORWARDS
        #elif self.left(obs, self.GOODGOALMULTI):
        #    newAction = self.actions.FORWARDSLEFT
        #elif self.right(obs, self.GOODGOALMULTI):
        #    newAction = self.actions.FORWARDSRIGHT
        #else:
            #if self.prev_action == self.actions.NOOP or self.prev_action == self.actions.BACKWARDS:
        #    """
        #    KV Addition: if the agent cannot see a goodgoal, multigoal, or badgoal, then pick a random action
        #    The agent has a 'step_length'/'step_length+1' probability of taking the action it just took, or of taking a new action
        #    """
        #    take_steps = random.randint(0, step_length) 
        #    if take_steps != 0:
        #        newAction = self.prev_action
        #    else:
        #        rand_action = random.randint(0,8) # pick one of 9 actions randomly
        #        if (rand_action == 0):
        #            newAction = self.actions.NOOP
        #        elif (rand_action == 1):
        #            newAction = self.actions.FORWARDS
        #        elif (rand_action == 2): 
        #            newAction = self.actions.FORWARDSRIGHT
        #        elif (rand_action == 3):
        #            newAction = self.actions.RIGHT
        #        elif (rand_action == 4):
        #            newAction = self.actions.BACKWARDSRIGHT
        #        elif (rand_action == 5):
        #            newAction = self.actions.BACKWARDS
        #        elif (rand_action == 6):
        #            newAction = self.actions.BACKWARDSLEFT
        #        elif (rand_action == 7):
        #            newAction = self.actions.LEFT
        #        else:
        #            newAction = self.actions.FORWARDSLEFT
        """
        NS Addition: If observation shows green at left_half, then after going forward turn left. Otherwise turn right. 
        """
        # Making sure that the base actions are still being carried out despite the last seen position of the goal
        if self.left(obs, self.GOODGOAL):
            self.last_saw_goal_left = True
            self.last_saw_goal_right = False
            self.last_saw_goal_ahead = False  
        elif self.right(obs, self.GOODGOAL):
            self.last_saw_goal_right = True
            self.last_saw_goal_left = False
            self.last_saw_goal_ahead = False  
        elif self.ahead(obs, self.GOODGOAL):
            self.last_saw_goal_ahead = True
            self.last_saw_goal_left = False  
            self.last_saw_goal_right = False 

        
        
         
 

        if self.last_saw_goal_left == True:
            if movement[2] < 15: 
                newAction = self.actions.FORWARDS
                print("Moving forward")
                #self.last_saw_goal_left = False 
                self.consecutive_steps_in_same_direction = 0
            elif self.consecutive_steps_in_same_direction < 5:
                newAction = self.actions.FORWARDSLEFT
                print("Moving forwardsleft")
                #self.consecutive_steps_in_same_direction += 1
            elif 5 <= self.consecutive_steps_in_same_direction < 15:
                newAction = self.actions.FORWARDS
                print("Moving forward after moving forwardsleft")
                #self.consecutive_steps_in_same_direction += 1
            else:
                newAction = self.actions.NOOP
        else:
            self.consecutive_steps_in_same_direction = 0

        if  self.last_saw_goal_right == True:
            if movement[2] < 15 == True: 
                newAction = self.actions.FORWARDS
                print("Moving forward")
                #self.last_saw_goal_right = False
                self.consecutive_steps_in_same_direction = 0
            elif self.consecutive_steps_in_same_direction < 5 : 
                newAction = self.actions.FORWARDSRIGHT
                print("Moving forwardsright")
                #self.consecutive_steps_in_same_direction += 1
            elif 5 <= self.consecutive_steps_in_same_direction <15:
                newAction = self.actions.FORWARDS
                print("Moving forward after moving forwardright")
                #self.consecutive_steps_in_same_direction += 1
            else:
                newAction = self.actions.NOOP
        else: 
            self.consecutive_steps_in_same_direction = 0

        if self.last_saw_goal_ahead == True:
           newAction = self.actions.FORWARDS
        
        if newAction in [self.actions.FORWARDS, self.actions.FORWARDSLEFT, self.actions.FORWARDSRIGHT]:
            self.consecutive_steps_in_same_direction += 1
        #    if self.consecutive_steps_in_same_direction >= 200:
        #        self.last_saw_goal_left = False
        #        self.last_saw_goal_right = False
        #        self.last_saw_goal_ahead = False
        #        print("Reset last_saw_goal!")
        #        self.consecutive_steps_in_same_direction = 0
        else:
            self.consecutive_steps_in_same_direction = 0
            print("reset consecutive steps")
        
        if self.last_saw_goal_right and self.last_saw_goal_left and self.last_saw_goal_ahead == False:
            if self.ahead(obs, self.GOODGOAL):
               newAction = self.actions.FORWARDS
            elif self.left(obs, self.GOODGOAL):
               newAction = self.actions.FORWARDSLEFT
            elif self.right(obs, self.GOODGOAL):
               newAction = self.actions.FORWARDSRIGHT
            elif self.ahead(obs, self.GOODGOALMULTI):
               newAction = self.actions.FORWARDS
            elif self.left(obs, self.GOODGOALMULTI):
               newAction = self.actions.FORWARDSLEFT
            elif self.right(obs, self.GOODGOALMULTI):
               newAction = self.actions.FORWARDSRIGHT
            else:
                rand_action = random.randint(0,8) # pick one of 9 actions randomly
                if (rand_action == 0):
                    newAction = self.actions.NOOP
                elif (rand_action == 1):
                    newAction = self.actions.FORWARDS
                elif (rand_action == 2): 
                    newAction = self.actions.FORWARDSRIGHT
                elif (rand_action == 3):
                    newAction = self.actions.RIGHT
                elif (rand_action == 4):
                    newAction = self.actions.BACKWARDSRIGHT
                elif (rand_action == 5):
                    newAction = self.actions.BACKWARDS
                elif (rand_action == 6):
                    newAction = self.actions.BACKWARDSLEFT
                elif (rand_action == 7):
                    newAction = self.actions.LEFT
                else:
                    newAction = self.actions.FORWARDSLEFT

        tolerance = 10 #The value for any of the three dimension which velocity is represented by
        
        #if any(abs(v) > tolerance for v in velocity):
        #   self.last_saw_goal_left = False
        #   self.last_saw_goal_right = False
        #   self.last_saw_goal_ahead = False  # Stop the action if velocity threshold is reache
        
        #Number of steps to move forward before turning (to avoid going around in circles straight away)
        #forward_steps = 10

        #Defining what actions should be done based on which is true
        
        """ 
        JL Addition: If the agent has been moving forwards towards a good goal for 3 timesteps, take 80 steps forwards but doing NOOP every third to prevent overshoot on 12 Cup (Grid) tasks
        """
        #if (self.ahead(obs, self.GOODGOAL) or self.ahead(obs, self.GOODGOALMULTI)) and newAction == self.actions.FORWARDS:
        #    self.forwards_counter += 1
        
        #if self.forwards_counter == 3:
        #    self.forwards_active = True

        #if self.forwards_active == True:
        #    if self.forwards_counter % 3 == 0:
        #        newAction = self.actions.NOOP
        #    else:
        #        newAction = self.actions.FORWARDS
        #    self.forwards_counter += 1
        
        #if self.forwards_counter >= 80:
        #    self.forwards_counter = 0
        #    self.forwards_active = False
        #    self.last_saw_goal_left = False
        #    self.last_saw_goal_right = False
        #    self.last_saw_goal_ahead = False


        self.prev_action = newAction
        return newAction


    def ahead(self, obs, object):
        """Returns true if the input object is ahead of the agent"""
        middle = obs[:, obs.shape[1]//2-1:obs.shape[1]//2+1, :]
        if np.any(np.all(middle == object, axis=-1)):
            print("found good goal middle!")
            return True
        else:
            return False

    def left(self, obs, object):
        """Returns true if the input object is left of the agent"""
        left_half = obs[:, :obs.shape[1]//2, :]
        if np.any(np.all(left_half == object, axis=-1)):
            print("found goal left!")
            return True
        else:
            return False


    def right(self, obs, object):
        """Returns true if the input object is right of the agent"""
        right_half = obs[:, obs.shape[1]//2:, :]
        if np.any(np.all(right_half == object, axis=-1)):
            print("found goal right!")
            return True
        else:
            return False

# %%
random.seed(aai_seed) #set seed for random action selection

port = 5005 + random.randint(
    0, 1000
)  # use a random port to avoid problems if a previous version exits slowly

aai_env = AnimalAIEnvironment( 
    inference=agent_inference,
    seed = aai_seed,
    log_folder = log_folder_path,
    worker_id=aai_seed,
    file_name=env_path,
    arenas_configurations=configuration_file,
    base_port=port,
    useCamera=True,
    resolution=1080,
    useRayCasts=False,
)
env = UnityToGymWrapper(aai_env, uint8_visual=True, allow_multiple_obs=False, flatten_branched=True)

#obs = env.reset()


braitenbergAgent = Braitenberg(STEP_LENGTH)
behavior = list(aai_env.behavior_specs.keys())[0] # by default should be AnimalAI?team=0

reward_list = []
firststep = True
for _episode in range(NUM_EPISODES): #Run episodes with the Braitenberg-style agent
    if firststep:
        aai_env.step() # Need to make a first step in order to get an observation.
        firstep = False
    dec, term = aai_env.get_steps(behavior)
    done = False
    episodeReward = 0
    while not done:
        camera = aai_env.get_obs_dict(dec.obs)["camera"] # Get the camera data
        velocity = aai_env.get_obs_dict(dec.obs)["velocity"]
        movement = aai_env.get_obs_dict(dec.obs)["position"]
        print(movement) 
        action = braitenbergAgent.get_action_camera(camera, STEP_LENGTH, velocity)
        aai_env.set_actions(behavior, action.action_tuple)
        aai_env.step()
        dec, term = aai_env.get_steps(behavior)
        if len(dec.reward) > 0:
            episodeReward += dec.reward
        if len(term) > 0: #Episode is over
            episodeReward += term.reward
            print(F"Episode Reward: {episodeReward}")
            reward_list.append(episodeReward)
            done = True
            firststep = True 
aai_env.close()

reward_df = pd.DataFrame(reward_list, columns = ['finalRewards'])

csv_path = log_folder_path + "/" + agent_name + "_Seed_" + str(aai_seed) + "_StepLength_" + str(STEP_LENGTH) + ".csv"
reward_df.to_csv(csv_path, index = False)
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# [WARNING] The environment contains multiple observations. You must define allow_multiple_obs=True to receive them all. Otherwise, only the first visual observation (or vector observation ifthere are no visual observations) will be provided in the observation.
# [20.       12.473212  2.      ]
# found goal left!
# Moving forward
# [20.       12.410187  2.      ]
# found goal left!
# Moving forward
# [20.       12.319916  2.      ]
# found goal left!
# Moving forward
# [20.       12.204933  2.      ]
# found goal left!
# Moving forward
# [20.       12.067535  2.      ]
# found goal left!
# Moving forward
# [20.       11.909806  2.      ]
# found goal left!
# Moving forward
# [20.       11.733636  2.      ]
# found goal left!
# Moving forward
# [20.      11.54074  2.     ]
# found goal left!
# Moving forward
# [20.       11.332672  2.      ]
# found goal left!
# Moving forward
# [20.       11.110842  2.      ]
# found goal left!
# Moving forward
# [20.000011 10.986574  2.007813]
# found goal left!
# Moving forward
# [19.99999   10.970252   2.1197488]
# found goal left!
# Moving forward
# [19.99997  10.916927  2.391651]
# found goal left!
# Moving forward
# [19.999952  10.835456   2.7876406]
# found goal left!
# Moving forward
# [19.999935  10.728456   3.1649594]
# found goal left!
# Moving forward
# [19.99993  10.61698   3.520877]
# found goal left!
# Moving forward
# [19.999918 10.502185  3.98838 ]
# found goal left!
# Moving forward
# [19.9999    10.3649845  4.581139 ]
# found goal left!
# Moving forward
# [19.99989   10.207435   5.2875185]
# found goal left!
# Moving forward
# [19.999878 10.031427  5.983255]
# found goal left!
# Moving forward
# [19.999874   9.8458185  6.612141 ]
# found goal left!
# Moving forward
# [19.999868  9.675885  7.286674]
# Moving forward
# [19.999857  9.488978  8.067124]
# Moving forward
# [19.999846  9.286343  8.943747]
# Moving forward
# [19.999834  9.069441  9.850141]
# Moving forward
# [19.999823   8.839599  10.6722765]
# Moving forward
# [19.99982   8.630392 11.465593]
# Moving forward
# [19.99981   8.414062 12.351899]
# Moving forward
# [19.9998    8.184737 13.324537]
# Moving forward
# [19.999794  7.943628 14.356122]
# Moving forward
# [19.999788   7.6918283 15.309951 ]
# Moving forwardsleft
# [19.99845   7.449999 16.188438]
# Moving forwardsleft
# [19.98011    7.2168937 17.128893 ]
# Moving forwardsleft
# [19.928295  6.972401 18.146786]
# Moving forwardsleft
# [19.82908   6.717533 19.230349]
# Moving forwardsleft
# [19.719069  6.453254 20.264423]
# Moving forwardsleft
# [19.608007   6.4837255 21.069834 ]
# Moving forwardsleft
# [19.40958    6.4839945 21.933474 ]
# Moving forwardsleft
# [19.152456  6.567616 22.740973]
# Moving forwardsleft
# [18.90654   6.610348 23.486435]
# Moving forwardsleft
# [18.683485   6.6160045 24.162596 ]
# Moving forwardsleft
# [18.481163  6.588032 24.775902]
# Moving forwardsleft
# [18.29765    6.5295553 25.332195 ]
# Moving forwardsleft
# [18.121046  6.484738 25.818243]
# Moving forwardsleft
# [17.849066   6.5079355 26.23167  ]
# Moving forwardsleft
# [17.495533  6.503983 26.615627]
# Moving forwardsleft
# [17.162872   6.4844465 26.95533  ]
# Moving forwardsleft
# [16.735302  6.483997 27.227728]
# Moving forwardsleft
# [16.309763   6.5885415 27.34392  ]
# Moving forwardsleft
# [15.833967   6.6670914 27.40506  ]
# Moving forwardsleft
# [15.402401   6.7052355 27.460516 ]
# Moving forwardsleft
# [15.010954   6.7067304 27.510818 ]
# Moving forwardsleft
# [14.655896  6.674983 27.556444]
# Moving forwardsleft
# [14.333845   6.6130824 27.59783  ]
# Moving forwardsleft
# [14.065642  6.583998 27.616108]
# Moving forwardsleft
# [13.769954   6.5838995 27.512327 ]
# Moving forwardsleft
# [13.429191   6.5726094 27.27818  ]
# Moving forwardsleft
# [13.07253   6.529254 26.965267]
# Moving forwardsleft
# [12.794451  6.514011 26.750595]
# Moving forwardsleft
# [12.613296   6.5844884 26.577892 ]
# Moving forwardsleft
# [12.433978  6.618585 26.255812]
# Moving forwardsleft
# [12.268779   6.6164083 25.908716 ]
# Moving forwardsleft
# [12.118937  6.581331 25.593887]
# Moving forwardsleft
# [12.025106  6.584214 25.294405]
# Moving forwardsleft
# [11.995137  6.583939 24.880808]
# Moving forwardsleft
# [12.035956   6.5831323 24.371181 ]
# Moving forwardsleft
# [12.1556635  6.5645943 23.771833 ]
# Moving forwardsleft
# [12.36336    6.5148244 23.09195  ]
# Moving forwardsleft
# [12.586625  6.436578 22.432722]
# Moving forwardsleft
# [12.700367   6.5307903 22.22091  ]
# Moving forwardsleft
# [12.907289   6.6146975 22.000414 ]
# Moving forwardsleft
# [13.19055   6.657134 21.742214]
# Moving forwardsleft
# [13.447479   6.6625223 21.508017 ]
# Moving forwardsleft
# [13.680524  6.634306 21.29559 ]
# Moving forwardsleft
# [13.891906  6.575609 21.102911]
# Moving forwardsleft
# [14.083636  6.489265 20.928144]
# Moving forwardsleft
# [14.266455  6.484049 20.813328]
# Moving forwardsleft
# [14.578838   6.4840083 20.734846 ]
# Moving forwardsleft
# [15.007364   6.4840074 20.70135  ]
# Moving forwardsleft
# [15.536503   6.4840055 20.723064 ]
# Moving forwardsleft
# [16.133404  6.505436 20.806747]
# Moving forwardsleft
# [16.73309    6.5433936 20.930222 ]
# Moving forwardsleft
# [17.277027   6.5447197 21.04222  ]
# Moving forwardsleft
# [17.770401  6.512819 21.143805]
# Moving forwardsleft
# [18.188534  6.502068 21.24381 ]
# Moving forwardsleft
# [18.634249   6.4858847 21.453014 ]
# Moving forwardsleft
# [19.099518   6.4840045 21.774017 ]
# Moving forwardsleft
# [19.557283   6.5152597 22.184248 ]
# Moving forwardsleft
# [19.998959   6.5308156 22.648773 ]
# Moving forwardsleft
# [20.399576   6.5118217 23.070116 ]
# Moving forwardsleft
# [20.75449    6.4845715 23.461243 ]
# Moving forwardsleft
# [21.054438  6.483997 23.93909 ]
# Moving forwardsleft
# [21.275877  6.538717 24.479067]
# Moving forwardsleft
# [21.430182  6.591628 25.051218]
# Moving forwardsleft
# [21.517933  6.606519 25.730473]
# Moving forwardsleft
# [21.568415   6.5869226 26.41492  ]
# Moving forwardsleft
# [21.565195   6.5684953 27.09721  ]
# Moving forwardsleft
# [21.525522  6.648493 27.615583]
# Moving forwardsleft
# [21.468712  6.749943 28.037024]
# Moving forwardsleft
# [21.417183   6.8088584 28.419287 ]
# Moving forwardsleft
# [21.370441  6.829194 28.766012]
# Moving forwardsleft
# [21.328049  6.814535 29.080507]
# Moving forwardsleft
# [21.289595  6.768135 29.365765]
# Moving forwardsleft
# [21.254717  6.692945 29.624506]
# Moving forwardsleft
# [21.22308    6.5916414 29.859194 ]
# Moving forwardsleft
# [21.194384  6.466651 30.072065]
# Moving forwardsleft
# [21.128412   6.4838767 30.167065 ]
# Moving forwardsleft
# [20.91585    6.4840007 30.235073 ]
# Moving forwardsleft
# [20.577717  6.484001 30.258883]
# Moving forwardsleft
# [20.130552  6.484    30.228739]
# Moving forwardsleft
# [19.676142   6.5422807 30.15131  ]
# Moving forwardsleft
# [19.247673  6.562037 30.073076]
# Moving forwardsleft
# [18.859035  6.546853 30.002115]
# Moving forwardsleft
# [18.506525   6.4999766 29.93775  ]
# Moving forwardsleft
# [18.185072   6.4841204 29.843683 ]
# Moving forwardsleft
# [17.836273   6.5035152 29.640205 ]
# Moving forwardsleft
# [17.454527  6.502733 29.332035]
# Moving forwardsleft
# [17.085459  6.484443 28.989544]
# Moving forwardsleft
# [16.718594  6.484003 28.540356]
# Moving forwardsleft
# [16.512924   6.6198187 28.08596  ]
# Moving forwardsleft
# [16.28878   6.686847 27.547136]
# Moving forwardsleft
# [16.085472   6.7145414 27.058403 ]
# Moving forwardsleft
# [15.901064   6.7065578 26.615103 ]
# Moving forwardsleft
# [15.733798   6.6662126 26.21301  ]
# Moving forwardsleft
# [15.582081  6.596514 25.848299]
# Moving forwardsleft
# [15.444468   6.5001917 25.517492 ]
# Moving forwardsleft
# [15.319647   6.3797197 25.217436 ]
# Moving forwardsleft
# [15.20643    6.2373433 24.945272 ]
# Moving forwardsleft
# [15.103738   6.0750985 24.69841  ]
# Moving forwardsleft
# [15.010592  5.894833 24.474497]
# Moving forwardsleft
# [14.9261055  5.6982217 24.2714   ]
# Moving forwardsleft
# [14.849472  5.486783 24.087183]
# Moving forwardsleft
# [14.779962  5.261897 23.920092]
# Moving forwardsleft
# [14.716914   5.0248127 23.768532 ]
# Moving forwardsleft
# [14.659727   4.7766643 23.631062 ]
# Moving forwardsleft
# [14.607856   4.5184803 23.506369 ]
# Moving forwardsleft
# [14.560807   4.2511935 23.393269 ]
# Moving forwardsleft
# [14.518131   3.9756508 23.290684 ]
# Moving forwardsleft
# [14.479423  3.692619 23.197634]
# Moving forwardsleft
# [14.444313   3.4027944 23.113234 ]
# Moving forwardsleft
# [14.412467   3.1068087 23.03668  ]
# Moving forwardsleft
# [14.383581   2.8052344 22.967241 ]
# Moving forwardsleft
# [14.357382  2.498591 22.904259]
# Moving forwardsleft
# [14.333617   2.1873498 22.847132 ]
# Moving forwardsleft
# [14.312063   1.8719383 22.795315 ]
# Moving forwardsleft
# [14.292512   1.5527443 22.748316 ]
# Moving forwardsleft
# [14.274778   1.2301191 22.705685 ]
# Moving forwardsleft
# [14.258694    0.90438193 22.667017  ]
# Moving forwardsleft
# [14.244103   0.5758218 22.631945 ]
# Moving forwardsleft
# [14.241565    0.48902884 22.635517  ]
# Moving forwardsleft
# [14.255949   0.4899922 22.782492 ]
# Moving forwardsleft
# [14.267682    0.48999995 23.065086  ]
# Moving forwardsleft
# [14.260507  0.49     23.469212]
# Moving forwardsleft
# [14.219967  0.49     23.98082 ]
# Moving forwardsleft
# [14.133365  0.49     24.585451]
# Moving forwardsleft
# [13.98978   0.49     25.268318]
# Moving forwardsleft
# [13.925934  0.49     25.502012]
# Moving forwardsleft
# [13.925128  0.49     25.50103 ]
# Moving forwardsleft
# [13.916207  0.49     25.500774]
# Moving forwardsleft
# [13.878012  0.49     25.500746]
# Moving forwardsleft
# [13.792164  0.49     25.500702]
# Moving forwardsleft
# [13.642294  0.49     25.500645]
# Moving forwardsleft
# [13.415278  0.49     25.500576]
# Moving forwardsleft
# [13.101169  0.49     25.500483]
# Moving forwardsleft
# [12.69257   0.49     25.500372]
# Moving forwardsleft
# [12.47197  0.49    25.50014]
# Moving forwardsleft
# [12.497916  0.49     25.500296]
# Moving forwardsleft
# [12.498313  0.49     25.50029 ]
# Moving forwardsleft
# [12.498548  0.49     25.500284]
# Moving forwardsleft
# [12.49869   0.49     25.500278]
# Moving forwardsleft
# [12.498777  0.49     25.500273]
# Moving forwardsleft
# [12.498831  0.49     25.500267]
# Moving forwardsleft
# [12.498916  0.49     25.499805]
# Moving forwardsleft
# [12.498924  0.49     25.488876]
# Moving forwardsleft
# [12.498965  0.49     25.44875 ]
# Moving forwardsleft
# [12.499032  0.49     25.360723]
# Moving forwardsleft
# [12.499125  0.49     25.208702]
# Moving forwardsleft
# [12.499252  0.49     24.979862]
# Moving forwardsleft
# [15.356512  0.49     25.501839]
# Moving forwardsleft
# [15.356504  0.49     25.501677]
# Moving forwardsleft
# [15.356145  0.49     25.501352]
# Moving forwardsleft
# [15.345061  0.49     25.501417]
# Moving forwardsleft
# [15.304556  0.49     25.501387]
# Moving forwardsleft
# [15.215744  0.49     25.50134 ]
# Moving forwardsleft
# [15.062449  0.49     25.501284]
# Moving forwardsleft
# [14.831761  0.49     25.501215]
# Moving forwardsleft
# [14.513683  0.49     25.501127]
# Moving forwardsleft
# [14.100804  0.49     25.501022]
# Moving forwardsleft
# [13.64245   0.49     25.445662]
# Moving forwardsleft
# [13.076964  0.49     25.39698 ]
# Moving forwardsleft
# [12.416185  0.49     25.336786]
# Moving forwardsleft
# [12.49806   0.49     25.336891]
# Moving forwardsleft
# [12.498439  0.49     25.336884]
# Moving forwardsleft
# [12.498662  0.49     25.336874]
# Moving forwardsleft
# [12.498796  0.49     25.336868]
# Moving forwardsleft
# [12.499089  0.49     25.336514]
# Moving forwardsleft
# [12.499012  0.49     25.325401]
# Moving forwardsleft
# [12.499052  0.49     25.285088]
# Moving forwardsleft
# [12.499118  0.49     25.196829]
# Moving forwardsleft
# Episode Reward: [-0.9967971]
# [19.971884   1.4876918  1.9512907]
# found goal left!
# Moving forward
# [19.94638    1.4343536  1.9071096]
# found goal left!
# Moving forward
# [19.923248   1.3528701  1.8670355]
# found goal left!
# Moving forward
# [19.908936   1.2878604  1.8422635]
# found goal left!
# Moving forward
# [19.908974   1.2887969  1.8422787]
# found goal left!
# Moving forward
# [19.908993   1.2888049  1.8422762]
# found goal left!
# Moving forward
# [19.909008   1.288805   1.8422726]
# found goal left!
# Moving forward
# [19.909023   1.288805   1.8422692]
# found goal left!
# Moving forward
# [19.909039   1.288805   1.8422656]
# found goal left!
# Moving forward
# [19.909052   1.2888049  1.8422618]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# found goal left!
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909058   1.288805   1.8422607]
# Moving forward
# [19.909044   1.288807   1.9425763]
# Moving forward
# [19.909039   1.2888057  2.1824303]
# Moving forward
# [19.909033   1.2888037  2.5488496]
# Moving forward
# [19.909027   1.2888008  3.0300686]
# Moving forward
# [19.909018   1.288797   3.6154158]
# Moving forward
# [19.909006   1.288792   4.2952113]
# Moving forward
# [19.908995   1.2887857  5.060675 ]
# Moving forward
# [19.908972   1.2664568  5.8978767]
# Moving forward
# [19.908955   1.2131002  6.675392 ]
# Moving forward
# [19.908937  1.1316    7.380629]
# Moving forward
# [19.90892    1.0245726  8.020307 ]
# Moving forward
# [19.908915   0.9892362  8.562972 ]
# Moving forward
# [19.908909    0.98946697  9.166542  ]
# Moving forward
# [19.9089     0.9894681  9.86299  ]
# Moving forward
# [19.908886    0.98946726 10.643559  ]
# Moving forward
# [19.908869   0.9894664 11.500428 ]
# Moving forward
# [19.908848   0.9894655 12.426503 ]
# Moving forward
# [19.908825   0.9894644 13.415351 ]
# Moving forward
# [19.908796    0.98946327 14.461137  ]
# Moving forward
# [19.908768   0.9894621 15.558567 ]
# Moving forwardsleft
# [19.906075  0.989461 16.70277 ]
# Moving forwardsleft
# [19.886099    0.98946035 17.888397  ]
# Moving forwardsleft
# [19.833467   0.9894611 19.108833 ]
# Moving forwardsleft
# [19.805895   0.9992786 19.28381  ]
# Moving forwardsleft
# [19.805685   1.0012156 19.275564 ]
# Moving forwardsleft
# [19.80542     0.99476916 19.264423  ]
# Moving forwardsleft
# [19.804594   0.9881295 19.247835 ]
# Moving forwardsleft
# [19.799387   0.9889201 19.250727 ]
# Moving forwardsleft
# [19.766531    0.98933935 19.250586  ]
# Moving forwardsleft
# [19.686527   0.9897183 19.250498 ]
# Moving forwardsleft
# [19.524946   0.9902559 19.25045  ]
# Moving forwardsleft
# [19.261005    0.99119157 19.250385  ]
# Moving forwardsleft
# [18.891373    0.99040955 19.25034   ]
# Moving forwardsleft
# [18.411985    0.97773445 19.250315  ]
# Moving forwardsleft
# [17.819704    0.94393045 19.250269  ]
# Moving forwardsleft
# [17.115349    0.88175976 19.247557  ]
# Moving forwardsleft
# [16.308819   0.7922635 19.22735  ]
# Moving forwardsleft
# [15.467968    0.67798334 19.188398  ]
# Moving forwardsleft
# [14.705283   0.5412231 19.153069 ]
# Moving forwardsleft
# [14.059912    0.49004036 19.114979  ]
# Moving forwardsleft
# [13.392395    0.49000028 19.007742  ]
# Moving forwardsleft
# [12.669976  0.49     18.815748]
# Moving forwardsleft
# [11.908342  0.49     18.534992]
# Moving forwardsleft
# [11.12298   0.49     18.162933]
# Moving forwardsleft
# [10.329051  0.49     17.698526]
# Moving forwardsleft
# [ 9.541276  0.49     17.142216]
# Moving forwardsleft
# [ 8.773816  0.49     16.495914]
# Moving forwardsleft
# [ 8.040156  0.49     15.762952]
# Moving forwardsleft
# [2.07701    0.48999998 0.49999812]
# Moving forward
# [2.0770092  0.48999998 0.49999812]
# Moving forward
# [2.0770085  0.48999998 0.49999812]
# Moving forward
# [2.0770078  0.48999998 0.49999812]
# Moving forward
# [2.077007   0.48999998 0.49999812]
# Moving forward
# [2.0770063  0.48999998 0.49999812]
# Moving forward
# [2.0770056  0.48999998 0.49999812]
# Moving forward
# [2.077005   0.48999998 0.49999812]
# Moving forward
# [2.0770042  0.48999998 0.49999812]
# Moving forward
# [2.0770035  0.48999998 0.49999812]
# Moving forward
# [2.0770028  0.48999998 0.49999812]
# Moving forward
# [2.077002   0.48999998 0.49999812]
# Moving forward
# [2.0770013  0.48999998 0.49999812]
# Moving forward
# [2.0770006  0.48999998 0.49999812]
# Moving forward
# [2.077      0.48999998 0.49999812]
# Moving forward
# [2.0769992  0.48999998 0.49999812]
# Moving forward
# [2.0769985  0.48999998 0.49999812]
# Moving forward
# [2.0769978  0.48999998 0.49999812]
# Moving forward
# [2.076997   0.48999998 0.49999812]
# Moving forward
# [2.0769963  0.48999998 0.49999812]
# Moving forward
# [2.0769956  0.48999998 0.49999812]
# Moving forward
# [2.076995   0.48999998 0.49999812]
# Moving forward
# [2.0769942  0.48999998 0.49999812]
# Moving forward
# [2.0769935  0.48999998 0.49999812]
# Moving forward
# [2.0769928  0.48999998 0.49999812]
# Moving forward
# [2.076992   0.48999998 0.49999812]
# Moving forward
# [2.0769913  0.48999998 0.49999812]
# Moving forward
# [2.0769906  0.48999998 0.49999812]
# Moving forward
# [2.07699    0.48999998 0.49999812]
# Moving forward
# [2.0769892  0.48999998 0.49999812]
# Moving forward
# [2.0769885  0.48999998 0.49999812]
# Moving forward
# [2.0769877  0.48999998 0.49999812]
# Moving forward
# [2.076987   0.48999998 0.49999812]
# Moving forward
# [2.0769863  0.48999998 0.49999812]
# Moving forward
# [2.0769856  0.48999998 0.49999812]
# Moving forward
# [2.076985   0.48999998 0.49999812]
# Moving forward
# [2.0769842  0.48999998 0.49999812]
# Moving forward
# [2.0769835  0.48999998 0.49999812]
# Moving forward
# [2.0769827  0.48999998 0.49999812]
# Moving forward
# [2.076982   0.48999998 0.49999812]
# Moving forward
# [2.0769813  0.48999998 0.49999812]
# Moving forward
# [2.0769806  0.48999998 0.49999812]
# Moving forward
# [2.0769799  0.48999998 0.49999812]
# Moving forward
# [2.0769792  0.48999998 0.49999812]
# Moving forward
# [2.0769784  0.48999998 0.49999812]
# Moving forward
# [2.0769777  0.48999998 0.49999812]
# Moving forward
# [2.076977   0.48999998 0.49999812]
# Moving forward
# [2.0769763  0.48999998 0.49999812]
# Moving forward
# [2.0769756  0.48999998 0.49999812]
# Moving forward
# [2.0769749  0.48999998 0.49999812]
# Moving forward
# [2.0769742  0.48999998 0.49999812]
# Moving forward

# %%
print(self.last_saw_goal_left)

# %%
movement[2]
# Out:
# 10.051034

# %%
aai_env.close()

# %%
import matplotlib.pyplot as plt
plt.imshow(camera[:,:,:])

# %%
plt.imshow(camera[210:215,105:110,:])

# %%
print(camera[260:262,230:232,:])
